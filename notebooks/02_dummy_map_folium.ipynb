# %%
import pandas as pd
import plotly.express as px
import folium

# %%
# center on Liberty Bell, add marker
campuses = [
    {"name": "Casa Central", "lat": -33.4489, "lon": -70.6610},
    {"name": "Facultad de Ciencias Físicas y Matemáticas", "lat": -33.4169, "lon": -70.6551},
    {"name": "Facultad de Ciencias Químicas y Farmacéuticas", "lat": -33.4586, "lon": -70.6633},
    {"name": "Facultad de Economía y Negocios", "lat": -33.4594, "lon": -70.6350},
    {"name": "Facultad de Medicina", "lat": -33.4196, "lon": -70.6498},
    {"name": "Facultad de Ciencias", "lat": -33.5403, "lon": -70.5739},
    {"name": "Facultad de Filosofía y Humanidades", "lat": -33.4628, "lon": -70.6544},
    {"name": "Facultad de Derecho", "lat": -33.4418, "lon": -70.6551},
    {"name": "Facultad de Ciencias Sociales", "lat": -33.4577, "lon": -70.6640},
    {"name": "Facultad de Arquitectura y Urbanismo", "lat": -33.4513, "lon": -70.6528},
    {"name": "Instituto de la Comunicación e Imagen", "lat": -33.4573, "lon": -70.6602},
]

m = folium.Map(zoom_start=16)
for campus in campuses:
    folium.Marker(
        [campus["lat"], campus["lon"]], popup=campus["name"], tooltip=campus["name"]
    ).add_to(m)

m.fit_bounds(m.get_bounds())
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5b8b6cf46314f404e86f063c861660a0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5b8b6cf46314f404e86f063c861660a0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5b8b6cf46314f404e86f063c861660a0 = L.map(
#                 &quot;map_5b8b6cf46314f404e86f063c861660a0&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_075d868a3f6a9c5565b6fe33bd542941 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_075d868a3f6a9c5565b6fe33bd542941.addTo(map_5b8b6cf46314f404e86f063c861660a0);
#
#
#             var marker_2250bc70f8a59b3f452598d75be9463f = L.marker(
#                 [-33.4489, -70.661],
#                 {}
#             ).addTo(map_5b8b6cf46314f404e86f063c861660a0);
#
#
#         var popup_7e1c8219048aaf4e0f45cfc869438063 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7846f6081cb88f3df53b3b07d07a2c10 = $(`&lt;div id=&quot;html_7846f6081cb88f3df53b3b07d07a2c10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Casa Central&lt;/div&gt;`)[0];
#                 popup_7e1c8219048aaf4e0f45cfc869438063.setContent(html_7846f6081cb88f3df53b3b07d07a2c10);
#
#
#
#         marker_2250bc70f8a59b3f452598d75be9463f.bindPopup(popup_7e1c8219048aaf4e0f45cfc869438063)
#         ;
#
#
#
#
#             marker_2250bc70f8a59b3f452598d75be9463f.bindTooltip(
#                 `&lt;div&gt;
#                      Casa Central
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8e00c568611b9f6b6ed8f725cd453a6d = L.marker(
#                 [-33.4169, -70.6551],
#                 {}
#             ).addTo(map_5b8b6cf46314f404e86f063c861660a0);
#
#
#         var popup_4273ccbef1b534660d8508b0e9965133 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2810708c813907ed532cad2edd8ba2bc = $(`&lt;div id=&quot;html_2810708c813907ed532cad2edd8ba2bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Facultad de Ciencias Físicas y Matemáticas&lt;/div&gt;`)[0];
#                 popup_4273ccbef1b534660d8508b0e9965133.setContent(html_2810708c813907ed532cad2edd8ba2bc);
#
#
#
#         marker_8e00c568611b9f6b6ed8f725cd453a6d.bindPopup(popup_4273ccbef1b534660d8508b0e9965133)
#         ;
#
#
#
#
#             marker_8e00c568611b9f6b6ed8f725cd453a6d.bindTooltip(
#                 `&lt;div&gt;
#                      Facultad de Ciencias Físicas y Matemáticas
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f326b9e656d25fda5ae149e24ad217ee = L.marker(
#                 [-33.4586, -70.6633],
#                 {}
#             ).addTo(map_5b8b6cf46314f404e86f063c861660a0);
#
#
#         var popup_d308c1d9ac993fa0802040720b9fa189 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1769da20ff5b74515e39ee2a5d54a7fe = $(`&lt;div id=&quot;html_1769da20ff5b74515e39ee2a5d54a7fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Facultad de Ciencias Químicas y Farmacéuticas&lt;/div&gt;`)[0];
#                 popup_d308c1d9ac993fa0802040720b9fa189.setContent(html_1769da20ff5b74515e39ee2a5d54a7fe);
#
#
#
#         marker_f326b9e656d25fda5ae149e24ad217ee.bindPopup(popup_d308c1d9ac993fa0802040720b9fa189)
#         ;
#
#
#
#
#             marker_f326b9e656d25fda5ae149e24ad217ee.bindTooltip(
#                 `&lt;div&gt;
#                      Facultad de Ciencias Químicas y Farmacéuticas
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_52f1228fa085d1566a0cf9183c631f41 = L.marker(
#                 [-33.4594, -70.635],
#                 {}
#             ).addTo(map_5b8b6cf46314f404e86f063c861660a0);
#
#
#         var popup_96394c3db850628d5cfa9edf0bbfc0f8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_df7288552bd3629508b24e872b8058cd = $(`&lt;div id=&quot;html_df7288552bd3629508b24e872b8058cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Facultad de Economía y Negocios&lt;/div&gt;`)[0];
#                 popup_96394c3db850628d5cfa9edf0bbfc0f8.setContent(html_df7288552bd3629508b24e872b8058cd);
#
#
#
#         marker_52f1228fa085d1566a0cf9183c631f41.bindPopup(popup_96394c3db850628d5cfa9edf0bbfc0f8)
#         ;
#
#
#
#
#             marker_52f1228fa085d1566a0cf9183c631f41.bindTooltip(
#                 `&lt;div&gt;
#                      Facultad de Economía y Negocios

# %%
type(m)
# Out:
# folium.folium.Map
